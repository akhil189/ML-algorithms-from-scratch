# %% [markdown]
# # Logistic Regression

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns

# %%
from ml_algs.logistic_regression import LogisticRegression

# %%
lr1 = LogisticRegression(tolerance=0.00005, learningRate=0.00001)

# %%
lr1.runModel()
# Out:
# X_train:(46, 2), y_train:(46,)
# X_test:(95, 2), y_test:(95,)
# 100%|██████████| 5000/5000 [00:00<00:00, 51534.55it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Training Accuracy: 0.9565217391304348
# Training Precision: 0.9722222222222222
# Training Recall: 0.9722222222222222
# Testing Accuracy: 0.8947368421052632
# Testing Precision: 0.9459459459459459
# Testing Recall: 0.9210526315789473

# %%
lr1.plot()

# %% [markdown]
# ### Logistic Regression with outliers removal

# %%
lr2 = LogisticRegression(tolerance=0.00005, learningRate=0.00001, outliers = [0, 38])

# %%
lr2.runModel()
# Out:
# X_train:(44, 2), y_train:(44,)
# X_test:(95, 2), y_test:(95,)
# 100%|██████████| 5000/5000 [00:00<00:00, 49493.93it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Training Accuracy: 1.0
# Training Precision: 1.0
# Training Recall: 1.0
# Testing Accuracy: 0.8947368421052632
# Testing Precision: 0.9459459459459459
# Testing Recall: 0.9210526315789473

# %%
lr2.scatterPlt()

# %%
lr2.plot()

# %% [markdown]
# ## 2nd approach for cost-function: Log-liklihood

# %%
lr1.runModel()
# Out:
# X_train:(46, 2), y_train:(46,)
# X_test:(95, 2), y_test:(95,)
# 100%|██████████| 5000/5000 [00:00<00:00, 45861.24it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Training Accuracy: 0.9565217391304348
# Training Precision: 0.9722222222222222
# Training Recall: 0.9722222222222222
# Testing Accuracy: 0.8947368421052632
# Testing Precision: 0.9459459459459459
# Testing Recall: 0.9210526315789473
